# %%
import os
import sys
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import multivariate_normal,beta,dirichlet,norm
from math import log
# %matplotlib inline
plt.style.use('ggplot')
np.random.seed(1234)
from scipy.special import gamma
import ternary


np.set_printoptions(formatter={'all':lambda x: '%.3f' % x})

# %%
p0 = norm(0,1)
alpha = 10
vh = beta(1,alpha)

# %%
p_x = []
p_y = []
breakoff = vh.rvs(size=1)
ratio = breakoff
product = 1-breakoff
while product>1e-10:
    print(f'product is: {product},ratio is: {ratio}')
    p_x.append(p0.rvs(size=1))
    p_y.append(ratio)
    breakoff = vh.rvs(size=1)
    ratio = breakoff*product
    product = product * (1-breakoff)
plt.figure()
plt.plot(p_x,p_y,'o')
# Out:
# product is: [0.973],ratio is: [0.027]
# product is: [0.934],ratio is: [0.038]
# product is: [0.880],ratio is: [0.054]
# product is: [0.877],ratio is: [0.003]
# product is: [0.872],ratio is: [0.005]
# product is: [0.818],ratio is: [0.054]
# product is: [0.789],ratio is: [0.030]
# product is: [0.772],ratio is: [0.016]
# product is: [0.640],ratio is: [0.132]
# product is: [0.639],ratio is: [0.001]
# product is: [0.590],ratio is: [0.050]
# product is: [0.584],ratio is: [0.006]
# product is: [0.520],ratio is: [0.064]
# product is: [0.472],ratio is: [0.048]
# product is: [0.404],ratio is: [0.068]
# product is: [0.398],ratio is: [0.006]
# product is: [0.369],ratio is: [0.029]
# product is: [0.361],ratio is: [0.008]
# product is: [0.357],ratio is: [0.004]
# product is: [0.303],ratio is: [0.055]
# product is: [0.210],ratio is: [0.093]
# product is: [0.209],ratio is: [0.001]
# product is: [0.196],ratio is: [0.013]
# product is: [0.194],ratio is: [0.002]
# product is: [0.186],ratio is: [0.008]
# ...

# %%
print(np.sum(p_y))
# Out:
# 0.9999999998959708
